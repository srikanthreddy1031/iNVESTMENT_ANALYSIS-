# %%
# task1
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv("data_set2.csv")
df.head()
# Out:
#    gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0  Female   34                Yes             1              2           5
# 1  Female   23                Yes             4              3           2
# 2    Male   30                Yes             3              6           4
# 3    Male   22                Yes             2              1           3
# 4  Female   24                 No             2              1           3
#
#    Government_Bonds  Fixed_Deposits  PPF  Gold  ...   Expect       Avenue  \
# 0                 3               7    6     4  ...  20%-30%  Mutual Fund
# 1                 1               5    6     7  ...  20%-30%  Mutual Fund
# 2                 2               5    1     7  ...  20%-30%       Equity
# 3                 7               6    4     5  ...  10%-20%       Equity
# 4                 6               4    5     7  ...  20%-30%       Equity
#
#   What are your savings objectives?         Reason_Equity  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 26 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   gender                             40 non-null     object
#  1   age                                40 non-null     int64
#  2   Investment_Avenues                 40 non-null     object
#  3   Mutual_Funds                       40 non-null     int64
#  4   Equity_Market                      40 non-null     int64
#  5   Debentures                         40 non-null     int64
#  6   Government_Bonds                   40 non-null     int64
#  7   Fixed_Deposits                     40 non-null     int64
#  8   PPF                                40 non-null     int64
#  9   Gold                               40 non-null     int64
#  10  Stock_Marktet                      40 non-null     object
# ...

# %%
print(df.head())
# Out:
#    gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0  Female   34                Yes             1              2           5
# 1  Female   23                Yes             4              3           2
# 2    Male   30                Yes             3              6           4
# 3    Male   22                Yes             2              1           3
# 4  Female   24                 No             2              1           3
#
#    Government_Bonds  Fixed_Deposits  PPF  Gold  ...   Expect       Avenue  \
# 0                 3               7    6     4  ...  20%-30%  Mutual Fund
# 1                 1               5    6     7  ...  20%-30%  Mutual Fund
# 2                 2               5    1     7  ...  20%-30%       Equity
# 3                 7               6    4     5  ...  10%-20%       Equity
# 4                 6               4    5     7  ...  20%-30%       Equity
#
#   What are your savings objectives?         Reason_Equity  \
# ...

# %%
print(df.describe())
# Out:
#              age  Mutual_Funds  Equity_Market  Debentures  Government_Bonds  \
# count  40.000000     40.000000      40.000000   40.000000         40.000000
# mean   27.800000      2.550000       3.475000    5.750000          4.650000
# std     3.560467      1.197219       1.131994    1.675617          1.369072
# min    21.000000      1.000000       1.000000    1.000000          1.000000
# 25%    25.750000      2.000000       3.000000    5.000000          4.000000
# 50%    27.000000      2.000000       4.000000    6.500000          5.000000
# 75%    30.000000      3.000000       4.000000    7.000000          5.000000
# max    35.000000      7.000000       6.000000    7.000000          7.000000
#
#        Fixed_Deposits        PPF       Gold  Duration_Numeric  Expect_Numeric
# count       40.000000  40.000000  40.000000         40.000000       40.000000
# mean         3.575000   2.025000   5.975000          2.975000       25.500000
# ...

# %%
# tASK 2
gender_column = df["gender"]
print(gender_column.head(49))
# Out:
# 0     Female
# 1     Female
# 2       Male
# 3       Male
# 4     Female
# 5     Female
# 6     Female
# 7       Male
# 8       Male
# 9       Male
# 10    Female
# 11      Male
# 12    Female
# 13    Female
# 14    Female
# 15      Male
# 16    Female
# 17      Male
# 18      Male
# 19      Male
# 20      Male
# 21    Female
# 22      Male
# 23      Male
# 24    Female
# 25    Female
# 26      Male
# 27      Male
# 28      Male
# 29    Female
# 30      Male
# 31    Female
# 32      Male
# 33      Male
# 34      Male
# 35      Male
# 36      Male
# 37      Male
# 38      Male
# 39      Male
# Name: gender, dtype: object

# %%
gender_counts = gender_column.value_counts()

# %%
 plt.figure(figsize=(8, 6))
gender_counts.plot(kind='bar', color=['blue', 'red'])
plt.title('Gender Distribution')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()

# %%
plt.figure(figsize=(8, 6))
gender_counts.plot(kind='pie', autopct='%1.1f%%', colors=['blue', 'red'], startangle=90, legend=True)
plt.title('Gender Distribution')
plt.ylabel('')
plt.show()

# %%
#TASK 3
numerical_columns = df.select_dtypes(include=['number']).columns
print(numerical_columns)
# Out:
# Index(['age', 'Mutual_Funds', 'Equity_Market', 'Debentures',
#        'Government_Bonds', 'Fixed_Deposits', 'PPF', 'Gold', 'Duration_Numeric',
#        'Expect_Numeric'],
#       dtype='object')

# %%
stats = df[numerical_columns].agg(['mean', 'median', 'std'])
print(stats)
# Out:
#               age  Mutual_Funds  Equity_Market  Debentures  Government_Bonds  \
# mean    27.800000      2.550000       3.475000    5.750000          4.650000
# median  27.000000      2.000000       4.000000    6.500000          5.000000
# std      3.560467      1.197219       1.131994    1.675617          1.369072
#
#         Fixed_Deposits       PPF      Gold  Duration_Numeric  Expect_Numeric
# mean          3.575000  2.025000  5.975000          2.975000       25.500000
# median        3.500000  1.000000  6.000000          3.000000       25.000000
# std           1.795828  1.609069  1.143263          1.224483        4.500712

# %%
# TASK 4
investment_avenues_column = df['Avenue']
print(investment_avenues_column)
# Out:
# 0               Mutual Fund
# 1               Mutual Fund
# 2                    Equity
# 3                    Equity
# 4                    Equity
# 5               Mutual Fund
# 6                    Equity
# 7               Mutual Fund
# 8                    Equity
# 9            Fixed Deposits
# 10              Mutual Fund
# 11              Mutual Fund
# 12              Mutual Fund
# 13              Mutual Fund
# 14           Fixed Deposits
# 15              Mutual Fund
# 16           Fixed Deposits
# 17              Mutual Fund
# 18              Mutual Fund
# 19           Fixed Deposits
# 20              Mutual Fund
# 21                   Equity
# 22              Mutual Fund
# 23    Public Provident Fund
# 24    Public Provident Fund
# 25              Mutual Fund
# 26              Mutual Fund
# 27           Fixed Deposits
# 28                   Equity
# 29              Mutual Fund
# 30              Mutual Fund
# 31           Fixed Deposits
# 32                   Equity
# ...

# %%
investment_avenue_counts = investment_avenues_column.value_counts()
most_frequent_investment_avenue = investment_avenue_counts.idxmax()
highest_frequency = investment_avenue_counts.max()

# %%
print("Frequency of each investment avenue:")
print(investment_avenue_counts)
print("\nInvestment avenue with the highest frequency:")
print(f"{most_frequent_investment_avenue}: {highest_frequency} occurrences")
# Out:
# Frequency of each investment avenue:
# Mutual Fund              18
# Equity                   10
# Fixed Deposits            9
# Public Provident Fund     3
# Name: Avenue, dtype: int64
#
# Investment avenue with the highest frequency:
# Mutual Fund: 18 occurrences

# %%
colors = ['skyblue', 'lightgreen', 'coral', 'orchid', 'gold', 'lightblue', 'lightpink', 'lightgrey']

plt.figure(figsize=(10, 6))
investment_avenue_counts.plot(kind='bar', color=colors[:len(investment_avenue_counts)])
plt.title('Frequency of Investment Avenues')
plt.xlabel('Investment Avenue')
plt.ylabel('Frequency')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()  # Adjust layout to ensure everything fits without overlap
plt.show()

# %%
# TASK 5
# Import necessary libraries
import matplotlib.pyplot as plt
import pandas as pd

# Sample data: replace these with your actual summary data
investment_summary = {
    'Investment1_Reasons': {
        'word_counts': pd.Series({'growth': 20, 'profit': 15, 'safe': 10, 'diversify': 5, 'earn': 8}),
        'theme_counts': {'growth': 20, 'safety': 10, 'diversification': 5, 'returns': 8, 'knowledge': 3}
    },
    'Investment2_Reasons': {
        'word_counts': pd.Series({'income': 25, 'security': 18, 'low risk': 12, 'familiar': 6, 'spread': 7}),
        'theme_counts': {'growth': 15, 'safety': 18, 'diversification': 7, 'returns': 10, 'knowledge': 6}
    },
    # Add other investments as needed
}

overall_word_counts = pd.Series({'growth': 45, 'profit': 30, 'safe': 20, 'diversify': 10, 'earn': 16})
overall_theme_counts = {'growth': 35, 'safety': 28, 'diversification': 12, 'returns': 18, 'knowledge': 9}

# Function to plot word counts
def plot_word_counts(word_counts, title):
    word_counts.head(10).plot(kind='bar', color='skyblue')
    plt.title(title)
    plt.xlabel('Words')
    plt.ylabel('Frequency')
    plt.xticks(rotation=45, ha='right')
    plt.show()

# Function to plot theme counts
def plot_theme_counts(theme_counts, title):
    pd.Series(theme_counts).plot(kind='bar', color='lightgreen')
    plt.title(title)
    plt.xlabel('Themes')
    plt.ylabel('Occurrences')
    plt.xticks(rotation=45, ha='right')
    plt.show()

# Display and plot visualizations for each investment
for investment, summary in investment_summary.items():
    print(f"\nSummary of reasons for {investment}:")
    print("\nMost common words:")
    print(summary['word_counts'].head(10))
    plot_word_counts(summary['word_counts'], f'Most Common Words in {investment}')
    
    print("\nTheme counts:")
    for theme, count in summary['theme_counts'].items():
        print(f"{theme.capitalize()}: {count} occurrences")
    plot_theme_counts(summary['theme_counts'], f'Theme Counts in {investment}')

# Display and plot overall visualizations
print("\nOverall Summary of reasons for all investments:")
print("\nMost common words:")
print(overall_word_counts.head(20))
plot_word_counts(overall_word_counts, 'Most Common Words in All Investments')

print("\nOverall theme counts:")
for theme, count in overall_theme_counts.items():
    print(f"{theme.capitalize()}: {count} occurrences")
plot_theme_counts(overall_theme_counts, 'Theme Counts in All Investments')
# Out:
# Summary of reasons for Investment1_Reasons:
#
# Most common words:
# growth       20
# profit       15
# safe         10
# diversify     5
# earn          8
# dtype: int64
# Theme counts:
# Growth: 20 occurrences
# Safety: 10 occurrences
# Diversification: 5 occurrences
# Returns: 8 occurrences
# Knowledge: 3 occurrences
# Summary of reasons for Investment2_Reasons:
#
# Most common words:
# income      25
# security    18
# low risk    12
# familiar     6
# spread       7
# dtype: int64
# Theme counts:
# Growth: 15 occurrences
# Safety: 18 occurrences
# Diversification: 7 occurrences
# Returns: 10 occurrences
# Knowledge: 6 occurrences
# Overall Summary of reasons for all investments:
#
# Most common words:
# growth       45
# profit       30
# safe         20
# diversify    10
# earn         16
# dtype: int64
# Overall theme counts:
# Growth: 35 occurrences
# Safety: 28 occurrences
# Diversification: 12 occurrences
# Returns: 18 occurrences
# Knowledge: 9 occurrences

# %%
#TASK 5
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt

# Step 1: Load the dataset
# Replace 'your_dataset.csv' with the path to your dataset
df = pd.read_csv('data_set2.csv')

# List of columns containing reasons for each investment
investment_columns = ['Reason_Equity', 'Reason_Mutual', 'Reason_Bonds', 'Reason_FD']

# Dictionary to store aggregated reasons and themes
investment_summary = {}
overall_reasons = []

# Step 2 & 3: Explore Reasons Columns, Aggregate Reasons, and Summarize Reasons
for column in investment_columns:
    # Step 2: Explore Reasons Column
    reasons_column = df[column].dropna().str.lower()
    
    # Add reasons to the overall list
    overall_reasons.extend(reasons_column)
    
    # Split the reasons into individual words
    words = reasons_column.str.split(expand=True).stack()
    
    # Count the frequency of each word
    word_counts = words.value_counts()
    
    # If you have predefined themes, you can categorize reasons
    themes = {
        'growth': ['growth', 'increase', 'profit','High ','Interest' ,'Rates','capital' ,'appreciation'],
        'safety': ['safe', 'security', 'low risk', 'Safe ','investment','Risk Free','liquidity'],
        'diversification': ['diversify', 'variety', 'spread',' diversification'],
        'returns': ['return', 'income', 'earn','Fixed','Returns','Better','Returns','Assured', 'Returns','Dividend','Benefits',' Incentives'],
        'knowledge': ['know', 'understand', 'familiar'],
    }
    
    # Initialize a dictionary to hold theme counts
    theme_counts = {theme: 0 for theme in themes}
    
    # Count occurrences of each theme
    for theme, keywords in themes.items():
        for keyword in keywords:
            theme_counts[theme] += reasons_column.str.contains(keyword).sum()
    
    # Store summary for the current investment
    investment_summary[column] = {
        'word_counts': word_counts,
        'theme_counts': theme_counts
    }

# Step 4: Overall Summary
overall_reasons_series = pd.Series(overall_reasons)

# Split the reasons into individual words
overall_words = overall_reasons_series.str.split(expand=True).stack()

# Count the frequency of each word
overall_word_counts = overall_words.value_counts()

# Count occurrences of each theme
overall_theme_counts = {theme: 0 for theme in themes}
for theme, keywords in themes.items():
    for keyword in keywords:
        overall_theme_counts[theme] += overall_reasons_series.str.contains(keyword).sum()

# Function to plot word counts
def plot_word_counts(word_counts, title):
    word_counts.head(10).plot(kind='bar', color='skyblue')
    plt.title(title)
    plt.xlabel('Words')
    plt.ylabel('Frequency')
    plt.xticks(rotation=45, ha='right')
    plt.show()

# Function to plot theme counts
def plot_theme_counts(theme_counts, title):
    pd.Series(theme_counts).plot(kind='bar', color='lightgreen')
    plt.title(title)
    plt.xlabel('Themes')
    plt.ylabel('Occurrences')
    plt.xticks(rotation=45, ha='right')
    plt.show()

# Display the detailed summary for each investment and plot visualizations
for investment, summary in investment_summary.items():
    print(f"\nSummary of reasons for {investment}:")
    print("\nMost common words:")
    print(summary['word_counts'].head(10))
    plot_word_counts(summary['word_counts'], f'Most Common Words in {investment}')
    
    print("\nTheme counts:")
    for theme, count in summary['theme_counts'].items():
        print(f"{theme.capitalize()}: {count} occurrences")
    plot_theme_counts(summary['theme_counts'], f'Theme Counts in {investment}')

# Display the overall summary and plot visualizations
print("\nOverall Summary of reasons for all investments:")
print("\nMost common words:")
print(overall_word_counts.head(20))
plot_word_counts(overall_word_counts, 'Most Common Words in All Investments')

print("\nOverall theme counts:")
for theme, count in overall_theme_counts.items():
    print(f"{theme.capitalize()}: {count} occurrences")
plot_theme_counts(overall_theme_counts, 'Theme Counts in All Investments')
# Out:
# Summary of reasons for Reason_Equity:
#
# Most common words:
# capital         30
# appreciation    30
# dividend         8
# liquidity        2
# dtype: int64
# Theme counts:
# Growth: 60 occurrences
# Safety: 2 occurrences
# Diversification: 0 occurrences
# Returns: 0 occurrences
# Knowledge: 0 occurrences
# Summary of reasons for Reason_Mutual:
#
# Most common words:
# better             24
# returns            24
# fund               13
# diversification    13
# tax                 3
# benefits            3
# dtype: int64
# Theme counts:
# Growth: 0 occurrences
# Safety: 0 occurrences
# Diversification: 13 occurrences
# Returns: 24 occurrences
# Knowledge: 0 occurrences
# Summary of reasons for Reason_Bonds:
#
# Most common words:
# assured       26
# returns       26
# safe          13
# investment    13
# tax            1
# incentives     1
# dtype: int64
# Theme counts:
# Growth: 0 occurrences
# Safety: 26 occurrences
# Diversification: 0 occurrences
# Returns: 26 occurrences
# ...

# %%
# TASK 6
# Import necessary libraries
import pandas as pd

# Step 1: Load the dataset
# Replace 'your_dataset.csv' with the path to your dataset
df = pd.read_csv('data_set2.csv')

# Verify the column names to ensure we're using the correct one
print("Column names in the dataset:", df.columns)

# Step 2: Explore Savings Objectives Column
# Replace 'Savings_Objectives' with the actual column name in your dataset
savings_objectives_column = df['What are your savings objectives?'].dropna().str.lower().str.strip()

# Get unique savings objectives
unique_objectives = savings_objectives_column.unique()

# Create a list of descriptions for each unique objective
objective_descriptions = {'retirement': 'Savings intended to provide financial security during retirement years.',
    'emergency fund': 'Savings set aside for unexpected expenses or financial emergencies.',
    'education': 'Savings aimed at funding educational expenses for oneself or dependents.',
    'vacation': 'Savings accumulated to fund travel and leisure activities.',
    'home purchase': 'Savings targeted towards buying a home or property.',
    'investment': 'Savings allocated for investing in various financial instruments to grow wealth.',
    'health care': 'Savings reserved for medical expenses and healthcare needs.',
    'debt repayment': 'Savings aimed at paying off debts and liabilities.',
    'business': 'Savings intended for starting or expanding a business.',
    'car purchase': 'Savings set aside for buying a car or vehicle.',
    # Add more objectives as needed
}

# Clean and standardize the objectives to match the descriptions dictionary keys
standardized_objectives = {'retirement': 'retirement',
    'retirement plan': 'retirement',
    'emergency fund': 'emergency fund',
    'education': 'education',
    'vacation': 'vacation',
    'home purchase': 'home purchase',
    'investment': 'investment',
    'health care': 'health care',  # Assuming 'health care' needs to be matched to 'healthcare'
    'debt repayment': 'debt repayment',
    'business': 'business',
    'car purchase': 'car purchase',
    # Add any other variations or standardizations needed
}

# Display the list and descriptions of savings objectives
print("\nList of Main Savings Objectives and Their Descriptions:")
for objective in unique_objectives:
    standardized_objective = standardized_objectives.get(objective, objective)
    description = objective_descriptions.get(standardized_objective, 'No description available.')
    print(f"{objective.capitalize()}: {description}")
# Out:
# Column names in the dataset: Index(['gender', 'age', 'Investment_Avenues', 'Mutual_Funds', 'Equity_Market',
#        'Debentures', 'Government_Bonds', 'Fixed_Deposits', 'PPF', 'Gold',
#        'Stock_Marktet', 'Factor', 'Objective', 'Purpose', 'Duration',
#        'Invest_Monitor', 'Expect', 'Avenue',
#        'What are your savings objectives?', 'Reason_Equity', 'Reason_Mutual',
#        'Reason_Bonds', 'Reason_FD', 'Source', 'Duration_Numeric',
#        'Expect_Numeric'],
#       dtype='object')
#
# List of Main Savings Objectives and Their Descriptions:
# Retirement plan: Savings intended to provide financial security during retirement years.
# Health care: Savings reserved for medical expenses and healthcare needs.
# Education: Savings aimed at funding educational expenses for oneself or dependents.

# %%
da=df['What are your savings objectives?']
print(da.head(45).unique())
# Out:
# ['Retirement Plan' 'Health Care' 'Education']

# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Step 1: Load the dataset
# Replace 'your_dataset.csv' with the path to your dataset
df = pd.read_csv('data_set2.csv')

# Step 2: Specify the column you want to analyze
# Replace 'Savings_Objectives' with the actual column name in your dataset
column_name = 'What are your savings objectives?'

# Step 3: Count unique values in the specified column
value_counts = df[column_name].value_counts()

# Step 4: Display the counts
print(f"Counts of unique values in the '{column_name}' column:")
print(value_counts)

# Step 5: Visualize the counts with a bar chart
plt.figure(figsize=(8, 6))
sns.barplot(x=value_counts.index, y=value_counts.values, palette='viridis')
plt.xlabel('Savings Objectives')
plt.ylabel('Counts')
plt.title(f'Counts of Unique Values in the {column_name} Column')
plt.xticks(rotation=45, ha='right')
plt.show()
# Out:
# Counts of unique values in the 'What are your savings objectives?' column:
# Retirement Plan    24
# Health Care        13
# Education           3
# Name: What are your savings objectives?, dtype: int64

# %%
#TASK 7
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Step 1: Load the dataset
# Replace 'your_dataset.csv' with the path to your dataset
df = pd.read_csv('data_set2.csv')

# Step 2: Explore the Information Sources Column
# Replace 'Information_Sources' with the actual column name in your dataset
column_name = 'Source'

# Step 3: Identify Common Sources
# Split the column values if they contain multiple sources separated by commas
all_sources = df[column_name].dropna().str.split(',').explode().str.strip()

# Count the frequency of each source
source_counts = all_sources.value_counts()

# Step 4: Display the counts
print(f"Counts of unique values in the '{column_name}' column:")
print(source_counts)

# Step 5: Visualize the common sources with a bar chart
plt.figure(figsize=(10, 6))
sns.barplot(x=source_counts.index, y=source_counts.values, palette='viridis')
plt.xlabel('Information Sources')
plt.ylabel('Counts')
plt.title(f'Counts of Unique Values in the {column_name} Column')
plt.xticks(rotation=45, ha='right')
plt.show()
# Out:
# Counts of unique values in the 'Source' column:
# Financial Consultants       16
# Newspapers and Magazines    14
# Television                   6
# Internet                     4
# Name: Source, dtype: int64

# %%
# TASK  8
# Import necessary libraries
import pandas as pd

# Step 1: Load the dataset
# Replace 'your_dataset.csv' with the path to your dataset
df = pd.read_csv('data_set2.csv')

# Step 2: Examine the Investment Duration Column
# Replace 'Investment_Duration' with the actual column name in your dataset
column_name = 'Duration'

# Display the first few rows of the dataset to ensure the column exists
print("First few rows of the dataset:")
print(df.head())

# Step 3: Convert duration ranges to numerical values
# Define a function to convert duration ranges to average numerical values
def convert_duration(duration):
    if pd.isna(duration):
        return None
    duration = duration.strip().lower()
    if duration == 'less than 1 year':
        return 0.5
    elif duration == '1-3 years':
        return 2
    elif duration == '3-5 years':
        return 4
    elif duration == 'more than 5 years':
        return 6
    else:
        return None

# Apply the function to the duration column
df[column_name + '_numeric'] = df[column_name].apply(convert_duration)

# Step 4: Calculate the average investment duration
average_duration = df[column_name + '_numeric'].mean()

# Display the average duration
print(f"\nThe average investment duration is: {average_duration:.2f} years")

# Optional: Display the transformed dataset to verify changes
print("\nTransformed dataset with numeric durations:")
print(df.head(45))
# Out:
# First few rows of the dataset:
#    gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0  Female   34                Yes             1              2           5
# 1  Female   23                Yes             4              3           2
# 2    Male   30                Yes             3              6           4
# 3    Male   22                Yes             2              1           3
# 4  Female   24                 No             2              1           3
#
#    Government_Bonds  Fixed_Deposits  PPF  Gold  ...   Expect       Avenue  \
# 0                 3               7    6     4  ...  20%-30%  Mutual Fund
# 1                 1               5    6     7  ...  20%-30%  Mutual Fund
# 2                 2               5    1     7  ...  20%-30%       Equity
# 3                 7               6    4     5  ...  10%-20%       Equity
# 4                 6               4    5     7  ...  20%-30%       Equity
#
# ...

# %%
df[column_name] = df[column_name].apply(convert_duration)

# Count the frequency of each duration
duration_counts = df[column_name].value_counts()

# Plotting a pie chart
plt.figure(figsize=(6, 6))
plt.pie(duration_counts, labels=duration_counts.index, autopct='%1.1f%%', colors=['#ff9999','#66b3ff','#99ff99','#ffcc99'])
plt.title('Investment Duration Distribution')
plt.show()

# %%
# TASK 9
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt

# Load your dataset (replace 'your_dataset.csv' with your actual dataset path)
df = pd.read_csv('data_set2.csv')

# Assuming 'Expectation_Range' is the column containing the expectation ranges
# Count the occurrences of each expectation range
expectation_counts = df['Expect'].value_counts()

# Print the counts to verify
print("Counts of each expectation range:")
print(expectation_counts)

# Plot the counts as a bar chart
expectation_counts.plot(kind='bar', figsize=(10, 6), color='skyblue', edgecolor='black')
plt.title('Counts of Common Expectations from Investments')
plt.xlabel('Expectation Ranges')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.grid(axis='y', linestyle='--')
plt.tight_layout()
plt.show()
# Out:
# Counts of each expectation range:
# 20%-30%    32
# 30%-40%     5
# 10%-20%     3
# Name: Expect, dtype: int64

# %%
#TASK 10
# Import necessary libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Load your dataset (replace 'your_dataset.csv' with your actual dataset path)
df = pd.read_csv('data_set2.csv')

# Display the first few rows of your dataset to understand its structure
print("First few rows of the dataset:")
print(df.head())

# Select relevant columns for correlation analysis
columns_to_analyze = ['age', 'Duration_Numeric', 'Expect_Numeric']

# Calculate correlation matrix
correlation_matrix = df[columns_to_analyze].corr()

# Print correlation matrix
print("\nCorrelation Matrix:")
print(correlation_matrix)

# Visualize correlation matrix as a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', vmin=-1, vmax=1)
plt.title('Correlation Matrix')
plt.show()

# Visualize correlations using pairplot (optional)
sns.pairplot(df[columns_to_analyze])
plt.suptitle('Pairplot of Age, Investment Duration, and Expected Returns', y=1.02)
plt.show()
# Out:
# First few rows of the dataset:
#    gender  age Investment_Avenues  Mutual_Funds  Equity_Market  Debentures  \
# 0  Female   34                Yes             1              2           5
# 1  Female   23                Yes             4              3           2
# 2    Male   30                Yes             3              6           4
# 3    Male   22                Yes             2              1           3
# 4  Female   24                 No             2              1           3
#
#    Government_Bonds  Fixed_Deposits  PPF  Gold  ...   Expect       Avenue  \
# 0                 3               7    6     4  ...  20%-30%  Mutual Fund
# 1                 1               5    6     7  ...  20%-30%  Mutual Fund
# 2                 2               5    1     7  ...  20%-30%       Equity
# 3                 7               6    4     5  ...  10%-20%       Equity
# 4                 6               4    5     7  ...  20%-30%       Equity
#
# ...

# %%
# TASK 10
import pandas as pd

# Load the dataset
data = pd.read_csv('data_set2.csv')
# Select relevant columns
relevant_columns = data[['age', 'Duration_Numeric', 'Expect_Numeric']]
# Calculate correlation matrix
correlation_matrix = relevant_columns.corr()
print(correlation_matrix)
import matplotlib.pyplot as plt
import seaborn as sns

# Scatter plot between Age and Investment Duration
sns.scatterplot(x='age', y='Duration_Numeric', data=relevant_columns)
plt.title('Age vs Investment Duration')
plt.show()

# Scatter plot between Age and Expected Returns
sns.scatterplot(x='age', y='Expect_Numeric', data=relevant_columns)
plt.title('Age vs Expected Returns')
plt.show()

# Scatter plot between Investment Duration and Expected Returns
sns.scatterplot(x='Duration_Numeric', y='Expect_Numeric', data=relevant_columns)
plt.title('Investment Duration vs Expected Returns')
plt.show()

# Heatmap of correlation matrix
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
# Out:
#                        age  Duration_Numeric  Expect_Numeric
# age               1.000000          0.051756       -0.089606
# Duration_Numeric  0.051756          1.000000        0.258223
# Expect_Numeric   -0.089606          0.258223        1.000000
